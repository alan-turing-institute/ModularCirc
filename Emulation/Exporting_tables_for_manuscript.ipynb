# %%
import pandas as pd
import numpy as np
import os
import sys
import pickle

# %%
df = pd.read_pickle('../Emulation/Outputs/Output_2000_22params/Emulators/linear_models_and_r2_scores_2000.csv')

# %%
df_trunc = df.iloc[:,:3]
# Export as Markdown
markdown_table = df_trunc.to_latex(index=True)

print(markdown_table)
# Out:
# \begin{tabular}{lrrr}
# \toprule
#  & R2_Score & MSE & RSE \\
# \midrule
# 0 & 0.726457 & 1.105458 & 1.057506 \\
# 1 & 0.714323 & 0.762935 & 0.878528 \\
# 2 & 0.698990 & 0.541008 & 0.739798 \\
# 3 & 0.679376 & 0.403680 & 0.639043 \\
# 4 & 0.655743 & 0.322777 & 0.571430 \\
# 5 & 0.630411 & 0.277612 & 0.529945 \\
# 6 & 0.606771 & 0.253896 & 0.506804 \\
# 7 & 0.587313 & 0.242341 & 0.495137 \\
# 8 & 0.572748 & 0.237257 & 0.489916 \\
# 9 & 0.562528 & 0.235373 & 0.487967 \\
# 10 & 0.555669 & 0.234927 & 0.487504 \\
# 11 & 0.551229 & 0.235038 & 0.487620 \\
# 12 & 0.548464 & 0.235308 & 0.487899 \\
# 13 & 0.546829 & 0.235578 & 0.488179 \\
# 14 & 0.545948 & 0.235799 & 0.488407 \\
# 15 & 0.545562 & 0.235969 & 0.488584 \\
# 16 & 0.545500 & 0.236101 & 0.488720 \\
# 17 & 0.545653 & 0.236211 & 0.488834 \\
# 18 & 0.545952 & 0.236314 & 0.488941 \\
# 19 & 0.546355 & 0.236428 & 0.489058 \\
# 20 & 0.546840 & 0.236569 & 0.489205 \\
# 21 & 0.547396 & 0.236764 & 0.489407 \\
# ...
